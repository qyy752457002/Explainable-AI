# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
tables = ['Table 29', 'Table 30', 'Table 31', 'Table 32', 'Table 33', 'Table 34', 
          'Table 35', 'Table 36', 'Table 37', 'Table 38', 'Table 39', 'Table 40']

trace_fitness = [1.00, 1.00, 0.09, 1.00, 1.00, 1.00, 0.15, 1.00, 1.00, 1.00, 0.21, 1.00]
move_model_fitness = [1.00, 1.00, 0.91, 1.00, 1.00, 1.00, 0.98, 1.00, 1.00, 1.00, 0.99, 1.00]
move_log_fitness = [1.00, 1.00, 0.09, 1.00, 1.00, 1.00, 0.13, 1.00, 1.00, 1.00, 0.19, 1.00]

# Create the plot
plt.figure(figsize=(12, 6))

plt.plot(tables, trace_fitness, marker='o', label='Trace Fitness', linewidth=2, markersize=8)
plt.plot(tables, move_model_fitness, marker='s', label='Move-Model Fitness', linewidth=2, markersize=8)
plt.plot(tables, move_log_fitness, marker='^', label='Move-Log Fitness', linewidth=2, markersize=8)

plt.xlabel('Table')
plt.ylabel('Fitness Value')
plt.title('Fitness Metrics Across Table 29 to Table 40')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adjust layout to prevent clipping of tick-labels
plt.tight_layout()

# Show the plot
plt.show()

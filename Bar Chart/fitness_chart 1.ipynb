# %%
import matplotlib.pyplot as plt

# Data
tables = ['Table 5', 'Table 6', 'Table 7', 'Table 8', 'Table 9', 'Table 10', 
          'Table 11', 'Table 12', 'Table 13', 'Table 14', 'Table 15', 'Table 16']

trace_fitness = [0.10, 1.00, 1.00, 1.00, 1.00, 1.00, 1.00, 1.00, 0.15, 1.00, 0.12, 1.00]
move_model_fitness = [0.77, 1.00, 1.00, 1.00, 1.00, 1.00, 1.00, 1.00, 0.91, 1.00, 0.94, 1.00]
move_log_fitness = [0.10, 1.00, 1.00, 1.00, 1.00, 1.00, 1.00, 1.00, 0.15, 1.00, 0.11, 1.00]

# Create the plot
plt.figure(figsize=(12, 6))
plt.plot(tables, trace_fitness, marker='o', label='Trace Fitness', linewidth=2, markersize=8)
plt.plot(tables, move_model_fitness, marker='s', label='Move-Model Fitness', linewidth=2, markersize=8)
plt.plot(tables, move_log_fitness, marker='^', label='Move-Log Fitness', linewidth=2, markersize=8)

plt.title('Fitness Metrics Across Table 5 to Table 16')
plt.xlabel('Table')
plt.ylabel('Fitness Value')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adjust layout to prevent clipping of tick-labels
plt.tight_layout()

# Show the plot
plt.show()
